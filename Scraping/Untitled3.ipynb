# %%
from bs4 import BeautifulSoup
import requests

url = "http://movie.naver.com/movie/bi/mi/basic.nhn?code=102278"
a = requests.get(url)

# %%
soup = BeautifulSoup(a.content,'html.parser')

# %%
table = soup.find('dl', attrs = {'class': 'info_spec'})

# %%
a = soup.find_all('a')

# %%
for i in a:
    print i
# Out:
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# <a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="http://static.naver.net/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a>
# <a class="blind" href="#content" title="본문으로 이동">본문 바로가기</a>
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" title="naver로 바로가기"><img alt="NAVER" height="13" src="http://static.naver.net/movie/2013/07/logo_ci.png" width="62"/></a>
# <a class="svc_logo" href="/" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="http://static.naver.net/movie/2012/06/logo_svc.png" width="34"/></a>
# <a class="menu01" href="/" title="영화홈"><strong>영화홈</strong></a>
# ...

# %%
from HTMLParser import HTMLParser

def naver_mv_link():
   naver_mv_link = {}
   client_id = "4o3GICRV4DheCATOr_oj"
   client_secret = "qx1velboFy"
   for index in range(1):
   
#   for index in range(len(my_movie_data)):
       #encText = urllib.parse.quote("검색할 단어")
#       encText = my_movie_data[index][u'Mname']
       encText = 'Star Wars'

       url = "https://openapi.naver.com/v1/search/movie?query={}".format(encText) # json 결과
       # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과


       headers = {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret }
       res = requests.get(url,headers=headers)

       data = json.loads(res.text)
       #print res.text # url구조 확인

       h = HTMLParser()
       
       try :
           naver_mv_link[my_movie_data[index][u'Mname']] = h.unescape(data['items'][0]['link'])
       except :
           naver_mv_link[my_movie_data[index][u'Mname']] = u'N/A'
   
   return naver_mv_link

naver_mv_link = naver_mv_link()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-24-b2d47b291d91> in <module>()
#      31    return naver_mv_link
#      32
# ---> 33 naver_mv_link = naver_mv_link()
#
# <ipython-input-24-b2d47b291d91> in naver_mv_link()
#      19        res = requests.get(url,headers=headers)
#      20
# ---> 21        data = json.loads(res.text)
#      22        #print res.text # url구조 확인
#      23
#
# NameError: global name 'json' is not defined
